# %% [markdown]
# # Insurrance predection

# %%
#import all the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# make the plot for regression
variables = ['age', 'sex', 'bmi', 'children', 'smoker', 'region']

for var in variables:
    plt.figure() # Creating a rectangle (figure) for each plot
    # Regression Plot also by default includes
    # best-fitting regression line
    # which can be turned off via `fit_reg=False`
    sns.regplot(x=var, y='charges', data=df).set(title=f'Regression plot of {var} and Insurrance charges');
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[13], line 9
#       5 plt.figure() # Creating a rectangle (figure) for each plot
#       6 # Regression Plot also by default includes
#       7 # best-fitting regression line
#       8 # which can be turned off via `fit_reg=False`
# ----> 9 sns.regplot(x=var, y='charges', data=df).set(title=f'Regression plot of {var} and Insurrance charges');
#      10 plt.show()
#
# File c:\Users\C4 Mobiles Laptop\.conda\envs\ydate_profiling\lib\site-packages\seaborn\regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# File c:\Users\C4 Mobiles Laptop\.conda\envs\ydate_profiling\lib\site-packages\seaborn\regression.py:384, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     381     self.scatterplot(ax, scatter_kws)
#     383 if self.fit_reg:
# --> 384     self.lineplot(ax, line_kws)
#     386 # Label the axes
#     387 if hasattr(self.x, "name"):
#
# File c:\Users\C4 Mobiles Laptop\.conda\envs\ydate_profiling\lib\site-packages\seaborn\regression.py:429, in _RegressionPlotter.lineplot(self, ax, kws)
#     427 """Draw the model."""
#     428 # Fit the regression model
# --> 429 grid, yhat, err_bands = self.fit_regression(ax)
#     430 edges = grid[0], grid[-1]
#     432 # Get set default aesthetics
#
# File c:\Users\C4 Mobiles Laptop\.conda\envs\ydate_profiling\lib\site-packages\seaborn\regression.py:209, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     207         else:
#     208             x_min, x_max = ax.get_xlim()
# --> 209     grid = np.linspace(x_min, x_max, 100)
#     210 ci = self.ci
#     212 # Fit the regression
#
# File c:\Users\C4 Mobiles Laptop\.conda\envs\ydate_profiling\lib\site-packages\numpy\_core\function_base.py:137, in linspace(start, stop, num, endpoint, retstep, dtype, axis, device)
#     135 conv = _array_converter(start, stop)
#     136 start, stop = conv.as_arrays()
# --> 137 dt = conv.result_type(ensure_inexact=True)
#     139 if dtype is None:
#     140     dtype = dt
#
# DTypePromotionError: The DType <class 'numpy.dtypes._PyFloatDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.StrDType'>, <class 'numpy.dtypes.StrDType'>, <class 'numpy.dtypes._PyFloatDType'>)
